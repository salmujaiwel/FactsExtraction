# %%
with open('Processed_forums_novels.txt', encoding='utf-8') as file:
    novels = file.read()
print(novels[:106])
# Out:
# قصه سواها قلبي ابو عبدالله الجد سلطان رجل اعمال كبير بالسنيتين الاخيره سلم كافة اعماله لعياله وهو ارتاااح

# %%
import nltk
from nltk.corpus import stopwords
nltk.download("stopwords")
arb_stopwords = set(nltk.corpus.stopwords.words("stopwords-ar"))

# Get Arabic stopwords and print some of them
arb_stopwords = (nltk.corpus.stopwords.words('stopwords-ar'))
arb_stopwords[:414]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\snmuj\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# ['مع',
#  'ومع',
#  'في',
#  'وفي',
#  'لم',
#  'ولم',
#  'الى',
#  'والى',
#  'التى',
#  'والتي',
#  'في',
#  'وفي',
#  'عن',
#  'وعن',
#  'من',
#  'ومن',
#  'إلى',
#  'وإلى',
#  'حتى',
#  'وحتى',
#  'خلا',
#  'حاشا',
#  'عدا',
#  'على',
#  'مذ',
#  'منذ',
#  'ومنذ',
#  'رب',
#  'ل',
#  'ك',
#  'ت',
#  'ب',
#  'لعل',
#  'ولعل',
#  'متى',
#  'ومتى',
#  'و',
#  'ف',
#  'ثم',
#  'أو',
#  'إذن',
#  'أم',
#  'لكن',
#  'بل',
#  'أيضا',
#  'كذلك',
#  'علاوة',
#  'رغم',
#  'الرغم',
#  'بحيث',
#  'قد',
#  'لقد',
#  'حيث',
#  'إذ',
#  'كيما',
#  'كيلا',
#  'إلا',
#  'سوى',
#  'غير',
#  'نعم',
#  'اللهم',
#  'كلا',
#  'أجل',
#  'هو',
#  'وهو',
#  'هي',
#  'وهي',
#  'هما',
#  'وهما',
#  'هم',
#  'وهم',
#  'هن',
#  'هذا',
#  'هذه',
#  'م',
#  'هذان',
#  'هاتان',
#  'هذين',
#  'هاتين',
#  'هؤلاء',
#  'أنت',
#  'أنتما',
#  'أنتم',
#  'أنتن',
# ...

# %%
from rake_nltk import Rake

# %%
rake = Rake(stopwords=stopwords.words('stopwords-ar'), punctuations=',./»:،؛":.,’،\''.split(), language='arabic', max_length=5)
rake.extract_keywords_from_text(novels)
for phrase in rake.get_ranked_phrases()[:20]:
 print(phrase)
# Out:
# ملاسن وصياح وتمشع بالشعور وقررنا
# غش وخدع وخان دينه وبلده
# تصيرعاتبني وبالعتاب أرتاحعاتبني وريحني وسامحني
# تابعنننني بخللف الكواليييس بدوون مايكوون
# بندريملونها بأكاذيبهم الباطله وتوقعاتهم الخاطئهإلين
# بنتظارنا لومزين ركبناها ورحنا لفندقنا
# المتعة والمناظر الجميلةومداخيلها الضخمه سنويا
# الصالات المفتوحة والتحف الموزعة بدقة
# الولادة وسافروا لديرتهم والعناوين مشيولة
# الاحمر امتزج بخيوط صفراء وبرتقاليه
# بعدي حمدي ربج بنقبل ناخذج
# هجر الحبايب مقتل سنيني يأست
# مقلم بالوردي بالعرض فصاير مزودني
# رسومات بالفوشي وبلوزه فوشيا ربط
# توبوا اليه يمتعكم متاعا حسنا
# قلللبه ووبحرج وبصوت اشبه للهممس
# ورق سولفان ومزين بعناية ومحطوط
# تتعلمين تقومينه لولواذا حج البقر
# إنتم سارامالك نيه ترجعينترى عفنتي
# وكم اشتاااقت للللللله ولحضننه اشتاااقت
